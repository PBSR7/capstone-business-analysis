# %%
import os
print(os.getcwd())
# Out:
# c:\Users\saira\OneDrive\Documents\GitHub\capstone-business-analysis\notebooks

# %%
print(os.listdir())
# Out:
# ['1_data_cleaning.ipynb', '2_eda.ipynb', '3_analysis.ipynb', 'data']

# %%
import os

print("Current Folder:", os.getcwd())
print("Files here:", os.listdir())

if "data" in os.listdir():
    print("Data folder contents:", os.listdir("data"))
else:
    print("❌ data folder not found")
# Out:
# Current Folder: c:\Users\saira\OneDrive\Documents\GitHub\capstone-business-analysis\notebooks
# Files here: ['1_data_cleaning.ipynb', '2_eda.ipynb', '3_analysis.ipynb', 'data']
# Data folder contents: ['cleaned_data.csv', 'customer_churn.csv', 'house_prices.csv', 'sales_data.csv']

# %%
import pandas as pd

# Load datasets
churn = pd.read_csv("data/customer_churn.csv")
sales = pd.read_csv("data/sales_data.csv")
house = pd.read_csv("data/house_prices.csv")

# Display basic info
print(churn.head())
print(churn.info())
# Out:
#   CustomerID  Tenure  MonthlyCharges  TotalCharges        Contract  \
# 0     C00001       6              64          1540        One year
# 1     C00002      21             113          1753  Month-to-month
# 2     C00003      27              31          1455        Two year
# 3     C00004      53              29          7150  Month-to-month
# 4     C00005      16             185          1023        One year
#
#       PaymentMethod PaperlessBilling  SeniorCitizen  Churn
# 0       Credit Card               No              1      0
# 1  Electronic Check              Yes              1      0
# 2       Credit Card               No              1      0
# 3  Electronic Check               No              1      0
# 4  Electronic Check               No              1      0
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        500 non-null    str
#  1   Tenure            500 non-null    int64
#  2   MonthlyCharges    500 non-null    int64
#  3   TotalCharges      500 non-null    int64
#  4   Contract          500 non-null    str
#  5   PaymentMethod     500 non-null    str
#  6   PaperlessBilling  500 non-null    str
#  7   SeniorCitizen     500 non-null    int64
#  8   Churn             500 non-null    int64
# dtypes: int64(5), str(4)
# memory usage: 35.3 KB
# None

# %%
# Check missing values
print(churn.isnull().sum())

# Fill or drop missing values
churn = churn.dropna()

# Remove duplicates
churn = churn.drop_duplicates()

# Convert categorical columns if needed
churn['Churn'] = churn['Churn'].astype('category')

# Save cleaned data
churn.to_csv("data/cleaned_data.csv", index=False)
# Out:
# CustomerID          0
# Tenure              0
# MonthlyCharges      0
# TotalCharges        0
# Contract            0
# PaymentMethod       0
# PaperlessBilling    0
# SeniorCitizen       0
# Churn               0
# dtype: int64
